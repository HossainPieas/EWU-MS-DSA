# %% [markdown]
# ***Final Project***
#
# *Student Name: Hossain Pieas*
#
# *Student ID: 2023-2-83-017*

# %% [markdown]
# ***Importing Liabraries***

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install scipy

# %%
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# ***Importing & Understanding The Dataset***

# %%
#importing the dataset
df = pd.read_csv('machine_sensor_dataset.csv')

# %%
df.columns

# %%
#reading first few (10) lines of the dataset
df.head(10)

# %%
df.tail(1)

# %%
df.info()

# %%
df.describe()

# %%
df.isnull().sum()

# %% [markdown]
# From here we understood how many null values there are.

# %%
#fill missing values with mean
df_mean = df.fillna(df.mean(), inplace=False)
print(df_mean)

# %%
df_sorted=df.sort_values(by=['Class'],ascending=True)
print(df_sorted)

# %%
df_sorted.corr()
# Out:
#                         Feature_1_Pressure  Feature_1_Temperature  \
# Feature_1_Pressure                1.000000              -0.022007
# Feature_1_Temperature            -0.022007               1.000000
# Feature_2_Pressure                0.004608              -0.014390
# Feature_2_Temperature             0.006656              -0.012680
# Feature_3_Pressure               -0.027438               0.009019
# ...                                    ...                    ...
# Feature_29_Pressure               0.015007              -0.017351
# Feature_29_Temperature            0.002647               0.028597
# Feature_30_Pressure               0.004590               0.001413
# Feature_30_Temperature            0.022611               0.002823
# Class                             0.005401               0.011500
#
#                         Feature_2_Pressure  Feature_2_Temperature  \
# Feature_1_Pressure                0.004608               0.006656
# ...
