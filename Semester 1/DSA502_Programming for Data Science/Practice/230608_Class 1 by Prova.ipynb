# %%
# **Intro to Python**

# %%
"""
name = input("What is your name?")
print(name)

"""
# Out:
# '\nname = input("What is your name?")\nprint(name)\n\n'

# %%
3+3
# Out:
# 6

# %%
3<5
# Out:
# True

# %%
from traitlets.traitlets import Int
num1 = int(input("Write 1st Number"))
num2 = int(input("Write 2nd number"))
sum = num1 + num2
print(f"The sum of these two numbers are {sum}")
# Out:
# Write 1st Number4
# Write 2nd number5
# The sum of these two numbers are 9

# %%
my_string = "Python is bad"
my_string
# Out:
# 'Python is bad'

# %%
type(my_string)
# Out:
# str

# %%
len(my_string)
# Out:
# 13

# %%
help(str.replace)
# Out:
# Help on method_descriptor:
#
# replace(self, old, new, count=-1, /)
#     Return a copy with all occurrences of substring old replaced by new.
#
#       count
#         Maximum number of occurrences to replace.
#         -1 (the default value) means replace all occurrences.
#
#     If the optional argument count is given, only the first count occurrences are
#     replaced.

# %%
my_string = "This is a simple string."

# %%
len(my_string)
# Out:
# 24

# %%
my_modified_string = my_string.replace("simple","complex")
print(my_modified_string)
# Out:
# This is a complex string.

# %%
2**3
# Out:
# 8

# %%
5%2
# Out:
# 1

# %%
5//2
# Out:
# 2

# %%
1/3
# Out:
# 0.3333333333333333

# %%
1//3
# Out:
# 0

# %%
1%3
# Out:
# 1
